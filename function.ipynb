# %%
import os, sys, argparse
from upsetplot import from_memberships
from upsetplot import plot
# %matplotlib inline 
from matplotlib import pyplot
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
from itertools import combinations
from comb import parse_maf, my_combs_frozenset, my_combs_all, my_combs, my_combos
from inter import intersections
#from howmany import how_many_tumor
from contents import set_contents
from df import baileydf, cgcdf, pancandf
from tabulate import tabulate

original = os.getcwd()

possible_callers = ('muse', 'mutect', 'somaticsniper', 'varscan')

possible_cancers = ('ACC', 'BLCA','BRCA','CESC','CHOL','COAD','DLBC','ESCA','GBM','HNSC', 
					'KICH','KIRC','KIRP','LAML','LGG','LIHC','LUAD','LUSC','MESO', 'OV','PAAD',
                    'PCPG','PRAD','READ','SARC','SKCM','STAD','TGCT','THCA','THYM','UCEC','UCS','UVM')

# %%
keys = my_combs_frozenset(possible_callers, len(possible_callers))

# %%
impacts = set(('MODERATE', 'HIGH'))
filt = set(('PASS',))
dfcgc = cgcdf(possible_cancers, possible_callers, keys, original, impacts, filt)
#print(dfcgc)

# %%
def table(callers, additional_callers, cancer, cardinality, impacts, filt, bcp):

    if isinstance(bcp, pd.DataFrame):
        if 'Total' in bcp.index:
            df = bcp.drop(['Total'], axis=0)
        else:
            df = bcp
    elif bcp == 'BAILEY':
        df = baileydf(possible_cancers, possible_callers, keys, original, impacts, filt).drop(['Total'], axis=0)
    elif bcp == 'CGC':
        df = cgcdf(possible_cancers, possible_callers, keys, original, impacts, filt).drop(['Total'], axis=0)
    elif bcp == 'PANCAN':
        df = pancandf(possible_cancers, possible_callers, keys, original, impacts, filt).drop(['Total'], axis=0)
    
    
    sets = []
    if len(callers) >= 1:
        sets.append(list(callers))
    ad = my_combs_all(additional_callers, len(additional_callers))

    for n in range(len(ad)):
        sets.append(callers+list(ad[n]))

    for i in range(len(sets)):
        sets[i] = tuple(sets[i])
    
    if len(callers) >= cardinality:
        sums = pd.DataFrame(0, index=sets, columns=('real', 'real % diff', 'total', 'total % diff', '% of all real'))
    else:
        sums = pd.DataFrame(0, index=sets, columns=('real', 'total', '% of all real'))
    
    # real counts
    su = []
    for i in range(len(sets)):
        index = []
        for j in range(len(keys)):
            if len(set(sets[i])&keys[j]) >= cardinality:
                index.append(j)
        s =[]
        for k in range(len(index)):
            s.append(df[cancer][index[k]])
        su.append(np.sum(s))
    sums.loc[:,'real'] = su
    
    # total counts
    tot = []
    for i in range(len(sets)):
        index = []
        for j in range(len(keys)):
            if len(set(sets[i])&keys[j]) >= 1:
                index.append(j)        
        t =[]
        for k in range(len(index)):
            t.append(df[cancer][index[k]])
        tot.append(np.sum(t))
    sums.loc[:,'total'] = tot
    
    
        # real fractions 
    realsum = 0
    for i in range(len(df[cancer])):
        if len(df.index[i]) >= cardinality:
            realsum += df[cancer][i]
    tops = np.array(sums.loc[:,'real'])
    fractions = 100*(tops/realsum)       
    sums.loc[:,'% of all real'] = fractions   
    
    if len(callers) >= cardinality:   
        # real percentage difference, with respect to the initial two way intersection
        rpercent = []
        for i in range(len(sets)):
            rpercent.append(100*((sums['real'][i] - sums['real'][0]) / sums['real'][0]))
        sums.loc[:,'real % diff'] = rpercent
    
    # total percentage difference, with respect to the initial two way intersection
        tpercent = []
        for i in range(len(sets)):
            tpercent.append(100*((sums['total'][i] - sums['total'][0]) / sums['total'][0]))
        sums.loc[:,'total % diff'] = tpercent
    
    #sort by real percentage difference values
        sums = sums.sort_values(['real % diff'], ascending=False)
    
    #print(cancer)
    if len(callers) >= cardinality: 
        print(tabulate(sums, headers=['variant callers', 'real', 'real % diff', 'total', 'total % diff', '% of all real'], tablefmt='psql',floatfmt=(".0f",".0f",".3f", ".0f", ".3f", ".3f")))
    else:
        print(tabulate(sums, headers=['variant callers', 'real', 'total', '% of all real'], tablefmt='psql',floatfmt=(".0f",".0f",".0f", ".3f")))
    print()
    
    return sums


callers = ['mutect','varscan','muse']
additional_callers = ['somaticsniper']
#cardinality = 2
for cancer in possible_cancers:
    print(cancer)
    print(callers, 'cardinality = 2')
    table(callers, additional_callers, cancer, 2, impacts, filt, bcp = dfcgc)
    
    print(callers, 'cardinality = 3')    
    table(callers, additional_callers, cancer, 3, impacts, filt, bcp = dfcgc)
    
    """
    callers = ['mutect','varscan','somaticsniper']
    additional_callers = ['muse']
    print(callers, 'cardinality = 3')
    table(callers, additional_callers, cancer, 3, impacts, filt, bcp = dfcgc)
    """
# Out:
# ACC
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    487 |        10.682 |     630 |          2.606 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    440 |         0.000 |     614 |          0.000 |          90.349 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    365 |        22.896 |     630 |          2.606 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    297 |         0.000 |     614 |          0.000 |          81.370 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# BLCA
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   6986 |         2.224 |    8384 |          0.311 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   6834 |         0.000 |    8358 |          0.000 |          97.824 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   5759 |        14.221 |    8384 |          0.311 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   5042 |         0.000 |    8358 |          0.000 |          87.550 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# BRCA
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   5573 |         1.734 |    7239 |          1.047 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   5478 |         0.000 |    7164 |          0.000 |          98.295 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   4172 |        11.164 |    7239 |          1.047 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   3753 |         0.000 |    7164 |          0.000 |          89.957 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# CESC
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   3725 |         1.748 |    4495 |          0.582 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   3661 |         0.000 |    4469 |          0.000 |          98.282 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   3211 |        14.352 |    4495 |          0.582 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2808 |         0.000 |    4469 |          0.000 |          87.449 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# CHOL
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    236 |         3.509 |     318 |          0.952 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    228 |         0.000 |     315 |          0.000 |          96.610 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    173 |        19.310 |     318 |          0.952 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    145 |         0.000 |     315 |          0.000 |          83.815 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# COAD
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |  11096 |         1.751 |   13432 |          0.344 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |  10905 |         0.000 |   13386 |          0.000 |          98.279 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   8407 |        13.439 |   13432 |          0.344 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   7411 |         0.000 |   13386 |          0.000 |          88.153 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# DLBC
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    457 |         5.543 |     569 |          0.708 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    433 |         0.000 |     565 |          0.000 |          94.748 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    382 |        24.430 |     569 |          0.708 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    307 |         0.000 |     565 |          0.000 |          80.366 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ESCA
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1745 |         3.377 |    2145 |          1.275 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1688 |         0.000 |    2118 |          0.000 |          96.734 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1366 |        16.852 |    2145 |          1.275 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1169 |         0.000 |    2118 |          0.000 |          85.578 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# GBM
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   2749 |         4.089 |    4621 |          0.239 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2641 |         0.000 |    4610 |          0.000 |          96.071 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   2237 |        20.140 |    4621 |          0.239 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1862 |         0.000 |    4610 |          0.000 |          83.236 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# HNSC
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   5266 |         1.503 |    6214 |          0.145 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   5188 |         0.000 |    6205 |          0.000 |          98.519 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   4253 |        11.015 |    6214 |          0.145 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   3831 |         0.000 |    6205 |          0.000 |          90.078 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# KICH
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    133 |         6.400 |     195 |          3.175 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    125 |         0.000 |     189 |          0.000 |          93.985 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    103 |        19.767 |     195 |          3.175 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |     86 |         0.000 |     189 |          0.000 |          83.495 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# KIRC
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1448 |         2.044 |    1841 |          0.546 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1419 |         0.000 |    1831 |          0.000 |          97.997 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    980 |         7.930 |    1841 |          0.546 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    908 |         0.000 |    1831 |          0.000 |          92.653 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# KIRP
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1071 |         2.783 |    1293 |          1.412 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1042 |         0.000 |    1275 |          0.000 |          97.292 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    818 |        10.690 |    1293 |          1.412 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    739 |         0.000 |    1275 |          0.000 |          90.342 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# LAML
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    311 |        28.512 |     699 |          7.209 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    242 |         0.000 |     652 |          0.000 |          77.814 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    136 |        25.926 |     699 |          7.209 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    108 |         0.000 |     652 |          0.000 |          79.412 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# LGG
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   2561 |         3.349 |    3274 |          0.153 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2478 |         0.000 |    3269 |          0.000 |          96.759 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1932 |        20.000 |    3274 |          0.153 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1610 |         0.000 |    3269 |          0.000 |          83.333 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# LIHC
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   2402 |         2.562 |    2867 |          0.596 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2342 |         0.000 |    2850 |          0.000 |          97.502 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1977 |        10.509 |    2867 |          0.596 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1789 |         0.000 |    2850 |          0.000 |          90.491 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# LUAD
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   9302 |         2.569 |   11034 |          0.327 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   9069 |         0.000 |   10998 |          0.000 |          97.495 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   7489 |        11.245 |   11034 |          0.327 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   6732 |         0.000 |   10998 |          0.000 |          89.892 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# LUSC
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   8284 |         2.423 |    9595 |          0.251 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   8088 |         0.000 |    9571 |          0.000 |          97.634 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   6871 |        10.520 |    9595 |          0.251 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   6217 |         0.000 |    9571 |          0.000 |          90.482 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# MESO
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    219 |         2.336 |     271 |          0.743 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    214 |         0.000 |     269 |          0.000 |          97.717 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    169 |        11.184 |     271 |          0.743 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    152 |         0.000 |     269 |          0.000 |          89.941 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# OV
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   2196 |         8.177 |    4282 |          0.281 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2030 |         0.000 |    4270 |          0.000 |          92.441 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1548 |        23.445 |    4282 |          0.281 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1254 |         0.000 |    4270 |          0.000 |          81.008 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# PAAD
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1425 |         0.636 |    1668 |          0.120 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1416 |         0.000 |    1666 |          0.000 |          99.368 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1064 |        10.031 |    1668 |          0.120 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    967 |         0.000 |    1666 |          0.000 |          90.883 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# PCPG
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    140 |         2.190 |     189 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    137 |         0.000 |     189 |          0.000 |          97.857 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    112 |         9.804 |     189 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    102 |         0.000 |     189 |          0.000 |          91.071 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# PRAD
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1410 |         2.026 |    1733 |          0.347 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1382 |         0.000 |    1727 |          0.000 |          98.014 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1061 |        14.579 |    1733 |          0.347 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    926 |         0.000 |    1727 |          0.000 |          87.276 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# READ
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   2998 |         2.112 |    3512 |          0.286 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2936 |         0.000 |    3502 |          0.000 |          97.932 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   2496 |        17.348 |    3512 |          0.286 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2127 |         0.000 |    3502 |          0.000 |          85.216 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# SARC
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    903 |         4.635 |    1265 |          2.429 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    863 |         0.000 |    1235 |          0.000 |          95.570 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    695 |        18.601 |    1265 |          2.429 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    586 |         0.000 |    1235 |          0.000 |          84.317 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# SKCM
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |  15410 |         2.222 |   16988 |          0.141 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |  15075 |         0.000 |   16964 |          0.000 |          97.826 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |  13593 |        15.420 |   16988 |          0.141 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |  11777 |         0.000 |   16964 |          0.000 |          86.640 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# STAD
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   9265 |         1.224 |   11165 |          0.161 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   9153 |         0.000 |   11147 |          0.000 |          98.791 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   6576 |        12.487 |   11165 |          0.161 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   5846 |         0.000 |   11147 |          0.000 |          88.899 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# TGCT
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    141 |         1.439 |     206 |          3.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    139 |         0.000 |     200 |          0.000 |          98.582 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    111 |         3.738 |     206 |          3.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    107 |         0.000 |     200 |          0.000 |          96.396 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# THCA
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    622 |         1.303 |     886 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    614 |         0.000 |     886 |          0.000 |          98.714 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    547 |         7.677 |     886 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    508 |         0.000 |     886 |          0.000 |          92.870 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# THYM
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    132 |         3.125 |     198 |          2.062 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    128 |         0.000 |     194 |          0.000 |          96.970 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    103 |        15.730 |     198 |          2.062 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |     89 |         0.000 |     194 |          0.000 |          86.408 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# UCEC
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |  33242 |         1.354 |   38136 |          0.187 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |  32798 |         0.000 |   38065 |          0.000 |          98.664 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |  28315 |        16.341 |   38136 |          0.187 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |  24338 |         0.000 |   38065 |          0.000 |          85.954 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# UCS
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    653 |         5.323 |     782 |          0.644 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    620 |         0.000 |     777 |          0.000 |          94.946 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    523 |        23.641 |     782 |          0.644 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    423 |         0.000 |     777 |          0.000 |          80.880 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# UVM
# ['mutect', 'varscan', 'muse'] cardinality = 2
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    199 |         6.417 |     257 |          1.181 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    187 |         0.000 |     254 |          0.000 |          93.970 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# ['mutect', 'varscan', 'muse'] cardinality = 3
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    169 |        11.921 |     257 |          1.181 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    151 |         0.000 |     254 |          0.000 |          89.349 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+

# %%
combos = my_combos(possible_callers, 2)
print('BRCA')
for j in range(len(combos)):    
    table(combos[j], set(possible_callers) - set(combos[j]), 'BRCA', 2, impacts, filt, bcp = dfcgc)
# Out:
# BRCA
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('muse', 'mutect', 'varscan', 'somaticsniper') |   5573 |        32.533 |    7239 |          7.595 |         100.000 |
# | ('muse', 'mutect', 'varscan')                  |   5478 |        30.273 |    7164 |          6.480 |          98.295 |
# | ('muse', 'mutect', 'somaticsniper')            |   4560 |         8.442 |    6873 |          2.155 |          81.823 |
# | ('muse', 'mutect')                             |   4205 |         0.000 |    6728 |          0.000 |          75.453 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('muse', 'somaticsniper', 'mutect', 'varscan') |   5573 |        68.879 |    7239 |         46.895 |         100.000 |
# | ('muse', 'somaticsniper', 'mutect')            |   4560 |        38.182 |    6873 |         39.468 |          81.823 |
# | ('muse', 'somaticsniper', 'varscan')           |   4313 |        30.697 |    6173 |         25.264 |          77.391 |
# | ('muse', 'somaticsniper')                      |   3300 |         0.000 |    4928 |          0.000 |          59.214 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('muse', 'varscan', 'mutect', 'somaticsniper') |   5573 |        38.322 |    7239 |         19.062 |         100.000 |
# | ('muse', 'varscan', 'mutect')                  |   5478 |        35.964 |    7164 |         17.829 |          98.295 |
# | ('muse', 'varscan', 'somaticsniper')           |   4313 |         7.049 |    6173 |          1.530 |          77.391 |
# | ('muse', 'varscan')                            |   4029 |         0.000 |    6080 |          0.000 |          72.295 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'somaticsniper', 'muse', 'varscan') |   5573 |        73.236 |    7239 |          8.857 |         100.000 |
# | ('mutect', 'somaticsniper', 'varscan')         |   5139 |        59.745 |    7080 |          6.466 |          92.212 |
# | ('mutect', 'somaticsniper', 'muse')            |   4560 |        41.747 |    6873 |          3.353 |          81.823 |
# | ('mutect', 'somaticsniper')                    |   3217 |         0.000 |    6650 |          0.000 |          57.725 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   5573 |        17.326 |    7239 |          3.444 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   5478 |        15.326 |    7164 |          2.372 |          98.295 |
# | ('mutect', 'varscan', 'somaticsniper')         |   5139 |         8.189 |    7080 |          1.172 |          92.212 |
# | ('mutect', 'varscan')                          |   4750 |         0.000 |    6998 |          0.000 |          85.232 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('somaticsniper', 'varscan', 'mutect', 'muse') |   5573 |        64.298 |    7239 |         28.101 |         100.000 |
# | ('somaticsniper', 'varscan', 'mutect')         |   5139 |        51.504 |    7080 |         25.288 |          92.212 |
# | ('somaticsniper', 'varscan', 'muse')           |   4313 |        27.152 |    6173 |          9.237 |          77.391 |
# | ('somaticsniper', 'varscan')                   |   3392 |         0.000 |    5651 |          0.000 |          60.865 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+

# %%
from howmany import how_many_tumor_cgc
def outlier_detector(dat, possible_callers, outliers, cancer, dfcgc):           
    os.chdir(original)
    cgc = pd.read_csv('Cancer_Gene_Census_all_Jun-11-2019.csv', usecols = (0,9))
    patients = set(list(dat[0].keys()))
    
    for i in range(len(dat)):
        patients = patients & set(list(dat[i].keys()))
    
    lengths = []
    
    patients = list(patients)
    
    for patient in patients:
        totalnumvariants = 0
        sets = []
        
        for j in range(len(dat)):
            sets.append(dat[j][patient])
            
        inters = intersections(sets)
        
        for j in range(len(inters)):
            totalnumvariants += len(inters[j])
        
        lengths.append(totalnumvariants)
    
    value = max(lengths)
    ind = lengths.index(max(lengths))
    outliers['maximum value'][cancer]= value
    outliers['patient index'][cancer]= ind
    
    
    data = dict([(key, []) for key in keys])

    sets = []
    for j in range(len(dat)):
        sets.append(dat[j][patients[ind]])
        
    inters = intersections(sets)
    for i in range(len(inters)):
        data[keys[i]].extend(list(inters[i]))
    
    #apply cgc filter     
    dfcgc.loc[:,cancer] = how_many_tumor_cgc(data, cgc, filt, impacts, keys)
    return outliers, dfcgc


outliers = pd.DataFrame(0, index=possible_cancers, columns=('maximum value', 'patient index'))
dfout = pd.DataFrame(np.nan, index=keys, columns=possible_cancers)
for cancer in possible_cancers:
    os.chdir(original)
    os.chdir(cancer)
    mafs = os.listdir()

    maf_fps = {}
    for caller in possible_callers:
        for maf in mafs:
            if caller in maf: # str in the filepath
                maf_fps[caller] = maf

    all_variants = {}
    
    for caller in maf_fps:
        all_variants[caller] = parse_maf(maf_fps[caller])
    arg = []
    for i in range(len(possible_callers)):
        arg.append(all_variants[possible_callers[i]])    
    test, data = outlier_detector(arg, possible_callers, outliers, cancer, dfout)
print(data)
print(test)



os.chdir(original)
# Out:
#                                         ACC  BLCA  BRCA  CESC  CHOL  COAD  \
# (muse)                                    0     2     5    12     4    10
# (mutect)                                  2     7    20    27     5    90
# (somaticsniper)                           1     1     0     1     0     2
# (varscan)                                 3     0     2    11     1    20
# (mutect, muse)                            0    10    24     7     1    46
# (muse, somaticsniper)                     0     0     0     3     0     1
# (muse, varscan)                           1     5    18     4     1    49
# (mutect, somaticsniper)                   0     6     0     0     1     2
# (mutect, varscan)                         5     3    16    27     3    56
# (varscan, somaticsniper)                  5     1     2     8     0     3
# (mutect, muse, somaticsniper)             1     0     0     0     1     1
# (mutect, muse, varscan)                   5     1   104    17     1   150
# (muse, somaticsniper, varscan)           12    20    13    82     5    27
# (mutect, varscan, somaticsniper)          1     0     2     4     2     9
# (mutect, muse, somaticsniper, varscan)   71   206   120   463    39   106
#
#                                         DLBC  ESCA  GBM  HNSC ...   READ  \
# (muse)                                     3     0   14     5 ...     21
# (mutect)                                   4     6   22    13 ...     20
# (somaticsniper)                            0     0    2     0 ...      0
# (varscan)                                  3     8    5    10 ...     16
# (mutect, muse)                             0     0   13    10 ...     23
# (muse, somaticsniper)                      0     1    1     0 ...      0
# (muse, varscan)                            1     0   30     1 ...      1
# (mutect, somaticsniper)                    0     0    0     0 ...      2
# (mutect, varscan)                          0    27   10    21 ...      4
# (varscan, somaticsniper)                   0     1    2     1 ...      1
# (mutect, muse, somaticsniper)              0     0    1     1 ...     15
# (mutect, muse, varscan)                    6     2  132    17 ...     10
# (muse, somaticsniper, varscan)             6    10   90     4 ...     77
# (mutect, varscan, somaticsniper)           0     2    2     1 ...      5
# (mutect, muse, somaticsniper, varscan)    23    50  399   115 ...    513
#
#                                         SARC  SKCM  STAD  TGCT  THCA  THYM  \
# (muse)                                     7    46     3     0     0     0
# (mutect)                                   0    28    39     0    33     2
# (somaticsniper)                            0     0     0     0     0     0
# (varscan)                                  1     8    20     0     0     2
# (mutect, muse)                             2    32    15     0     0     0
# (muse, somaticsniper)                      0     0     0     0     0     0
# (muse, varscan)                            2    33     4     0     0     0
# (mutect, somaticsniper)                    0     0     1     0     0     0
# (mutect, varscan)                          0    14    35     0     0    10
# (varscan, somaticsniper)                   0     1     2     0     0     0
# (mutect, muse, somaticsniper)              1     0     5     0     0     1
# (mutect, muse, varscan)                    9    78    17     2     0     1
# (muse, somaticsniper, varscan)             4   178    52     0     1     2
# (mutect, varscan, somaticsniper)           2     9     3     0     0     4
# (mutect, muse, somaticsniper, varscan)    75   485   265     1     0    16
#
#                                         UCEC  UCS  UVM
# (muse)                                    59    1    0
# (mutect)                                  40    8    3
# (somaticsniper)                            2    1    0
# (varscan)                                 16    0    1
# (mutect, muse)                            28    8    0
# (muse, somaticsniper)                      0    0    0
# (muse, varscan)                           89    1    1
# (mutect, somaticsniper)                    0    0    1
# (mutect, varscan)                         28    8    1
# (varscan, somaticsniper)                  10    2    0
# (mutect, muse, somaticsniper)              2    1    0
# (mutect, muse, varscan)                  243    9    0
# (muse, somaticsniper, varscan)           299   18    1
# (mutect, varscan, somaticsniper)          17    1    0
# (mutect, muse, somaticsniper, varscan)   777  199   14
#
# [15 rows x 33 columns]
#       maximum value  patient index
# ACC            3154             91
# BLCA           5724            179
# BRCA           8209            150
# CESC          22840            164
# CHOL           1534             45
# COAD          15912            166
# DLBC            690             21
# ESCA           4285             58
# GBM           19823            115
# HNSC           4557            393
# KICH           1225             22
# KIRC           2148            129
# KIRP            250            183
# LAML           2415             81
# LGG           17417             75
# LIHC           2422            357
# LUAD           3576            539
# LUSC           4683             79
# MESO            534             45
# OV             1647             46
# PAAD          26182              1
# PCPG             47              0
# PRAD          10668            419
# READ          20192             63
# SARC           3864            113
# SKCM          29634            420
# STAD          10761            184
# TGCT             82            126
# THCA            740            339
# THYM           1903             80
# UCEC          43889            321
# UCS            5722             36
# UVM             659              8

# %%
from operator import itemgetter

callers = ['mutect','varscan']
additional_callers = ['somaticsniper','muse']
dictofout = dict([(cancer, 0) for cancer in possible_cancers])
for cancer in possible_cancers:
    print(cancer)
    print('total')
    cgc = table(callers, additional_callers, cancer, 2, impacts, filt, bcp = dfcgc)
    print('outlier')
    out = table(callers, additional_callers, cancer, 2, impacts, filt, bcp = data)
    diff = pd.DataFrame(0, index=cgc.index, columns=('real %', 'total %', '% all'))
    diff['real %']= np.array(out['real % diff']) - np.array(cgc['real % diff'])
    diff['total %']= np.array(out['total % diff']) - np.array(cgc['total % diff'])
    diff['% all']= np.array(out['% of all real']) - np.array(cgc['% of all real'])
    print('difference between total and outlier')
    print(tabulate(diff, headers=['variant callers', 'real %', 'total %', '% all'], tablefmt='psql',floatfmt=(".0f",".3f",".3f", ".3f")))
    dictofout[cancer] = np.sum(np.array([abs(number) for number in diff['real %']]))
#print(sorted(dictofout.items(), key=itemgetter(1), reverse = True))
# Out:
# ACC
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    487 |        41.983 |     630 |          4.132 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |    451 |        31.487 |     625 |          3.306 |          92.608 |
# | ('mutect', 'varscan', 'muse')                  |    440 |        28.280 |     614 |          1.488 |          90.349 |
# | ('mutect', 'varscan')                          |    343 |         0.000 |     605 |          0.000 |          70.431 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    101 |        23.171 |     107 |          0.943 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |    100 |        21.951 |     107 |          0.943 |          99.010 |
# | ('mutect', 'varscan', 'muse')                  |     96 |        17.073 |     106 |          0.000 |          95.050 |
# | ('mutect', 'varscan')                          |     82 |         0.000 |     106 |          0.000 |          81.188 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |  -18.812 |    -3.189 |   0.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -9.536 |    -2.362 |   6.402 |
# | ('mutect', 'varscan', 'muse')                  |  -11.207 |    -1.488 |   4.700 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |  10.757 |
# +------------------------------------------------+----------+-----------+---------+
# BLCA
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   6986 |        21.898 |    8384 |          3.379 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   6834 |        19.246 |    8358 |          3.058 |          97.824 |
# | ('mutect', 'varscan', 'somaticsniper')         |   6475 |        12.982 |    8152 |          0.518 |          92.685 |
# | ('mutect', 'varscan')                          |   5731 |         0.000 |    8110 |          0.000 |          82.035 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    252 |        20.000 |     262 |          1.158 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    245 |        16.667 |     261 |          0.772 |          97.222 |
# | ('mutect', 'varscan', 'somaticsniper')         |    237 |        12.857 |     260 |          0.386 |          94.048 |
# | ('mutect', 'varscan')                          |    210 |         0.000 |     259 |          0.000 |          83.333 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -1.898 |    -2.220 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -2.580 |    -2.286 |  -0.602 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -0.125 |    -0.132 |   1.362 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   1.298 |
# +------------------------------------------------+----------+-----------+---------+
# BRCA
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   5573 |        17.326 |    7239 |          3.444 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   5478 |        15.326 |    7164 |          2.372 |          98.295 |
# | ('mutect', 'varscan', 'somaticsniper')         |   5139 |         8.189 |    7080 |          1.172 |          92.212 |
# | ('mutect', 'varscan')                          |   4750 |         0.000 |    6998 |          0.000 |          85.232 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    299 |        23.554 |     326 |          1.558 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    297 |        22.727 |     326 |          1.558 |          99.331 |
# | ('mutect', 'varscan', 'somaticsniper')         |    257 |         6.198 |     321 |          0.000 |          85.953 |
# | ('mutect', 'varscan')                          |    242 |         0.000 |     321 |          0.000 |          80.936 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    6.227 |    -1.886 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |    7.401 |    -0.814 |   1.036 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -1.991 |    -1.172 |  -6.259 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |  -4.296 |
# +------------------------------------------------+----------+-----------+---------+
# CESC
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   3725 |        18.104 |    4495 |          4.681 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   3661 |        16.075 |    4469 |          4.075 |          98.282 |
# | ('mutect', 'varscan', 'somaticsniper')         |   3531 |        11.953 |    4328 |          0.792 |          94.792 |
# | ('mutect', 'varscan')                          |   3154 |         0.000 |    4294 |          0.000 |          84.671 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    615 |        20.352 |     666 |          2.462 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    604 |        18.200 |     665 |          2.308 |          98.211 |
# | ('mutect', 'varscan', 'somaticsniper')         |    601 |        17.613 |     654 |          0.615 |          97.724 |
# | ('mutect', 'varscan')                          |    511 |         0.000 |     650 |          0.000 |          83.089 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    2.248 |    -2.219 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |    2.125 |    -1.768 |  -0.070 |
# | ('mutect', 'varscan', 'somaticsniper')         |    5.659 |    -0.176 |   2.932 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |  -1.582 |
# +------------------------------------------------+----------+-----------+---------+
# CHOL
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    236 |        18.593 |     318 |          3.583 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    228 |        14.573 |     315 |          2.606 |          96.610 |
# | ('mutect', 'varscan', 'somaticsniper')         |    227 |        14.070 |     311 |          1.303 |          96.186 |
# | ('mutect', 'varscan')                          |    199 |         0.000 |     307 |          0.000 |          84.322 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |     54 |        20.000 |      64 |          6.667 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |     53 |        17.778 |      64 |          6.667 |          98.148 |
# | ('mutect', 'varscan', 'somaticsniper')         |     52 |        15.556 |      60 |          0.000 |          96.296 |
# | ('mutect', 'varscan')                          |     45 |         0.000 |      60 |          0.000 |          83.333 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    1.407 |     3.084 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |    3.205 |     4.061 |   1.538 |
# | ('mutect', 'varscan', 'somaticsniper')         |    1.485 |    -1.303 |   0.110 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |  -0.989 |
# +------------------------------------------------+----------+-----------+---------+
# COAD
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |  11096 |        18.408 |   13432 |          1.596 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |  10905 |        16.370 |   13386 |          1.248 |          98.279 |
# | ('mutect', 'varscan', 'somaticsniper')         |  10417 |        11.162 |   13282 |          0.461 |          93.881 |
# | ('mutect', 'varscan')                          |   9371 |         0.000 |   13221 |          0.000 |          84.454 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    450 |        40.187 |     572 |          2.326 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    444 |        38.318 |     570 |          1.968 |          98.667 |
# | ('mutect', 'varscan', 'somaticsniper')         |    354 |        10.280 |     562 |          0.537 |          78.667 |
# | ('mutect', 'varscan')                          |    321 |         0.000 |     559 |          0.000 |          71.333 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   21.779 |     0.730 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   21.948 |     0.720 |   0.388 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -0.882 |     0.075 | -15.214 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 | -13.121 |
# +------------------------------------------------+----------+-----------+---------+
# DLBC
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    457 |        35.207 |     569 |          5.370 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    433 |        28.107 |     565 |          4.630 |          94.748 |
# | ('mutect', 'varscan', 'somaticsniper')         |    431 |        27.515 |     546 |          1.111 |          94.311 |
# | ('mutect', 'varscan')                          |    338 |         0.000 |     540 |          0.000 |          73.961 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse')                  |     36 |        24.138 |      46 |          6.977 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |     36 |        24.138 |      46 |          6.977 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |     35 |        20.690 |      43 |          0.000 |          97.222 |
# | ('mutect', 'varscan')                          |     29 |         0.000 |      43 |          0.000 |          80.556 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |  -11.069 |     1.606 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -3.969 |     2.347 |   5.252 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -6.825 |    -1.111 |   2.912 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   6.595 |
# +------------------------------------------------+----------+-----------+---------+
# ESCA
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   1745 |        18.385 |    2145 |          3.175 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1688 |        14.518 |    2118 |          1.876 |          96.734 |
# | ('mutect', 'varscan', 'somaticsniper')         |   1658 |        12.483 |    2117 |          1.828 |          95.014 |
# | ('mutect', 'varscan')                          |   1474 |         0.000 |    2079 |          0.000 |          84.470 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |     93 |        14.815 |     107 |          0.943 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |     92 |        13.580 |     107 |          0.943 |          98.925 |
# | ('mutect', 'varscan', 'muse')                  |     91 |        12.346 |     107 |          0.943 |          97.849 |
# | ('mutect', 'varscan')                          |     81 |         0.000 |     106 |          0.000 |          87.097 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -3.571 |    -2.231 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -0.938 |    -0.933 |   2.191 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -0.137 |    -0.884 |   2.835 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   2.627 |
# +------------------------------------------------+----------+-----------+---------+
# GBM
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   2749 |        29.976 |    4621 |          2.189 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2641 |        24.870 |    4610 |          1.946 |          96.071 |
# | ('mutect', 'varscan', 'somaticsniper')         |   2535 |        19.858 |    4555 |          0.730 |          92.215 |
# | ('mutect', 'varscan')                          |   2115 |         0.000 |    4522 |          0.000 |          76.937 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    680 |        25.230 |     723 |          2.408 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    677 |        24.678 |     721 |          2.125 |          99.559 |
# | ('mutect', 'varscan', 'somaticsniper')         |    636 |        17.127 |     709 |          0.425 |          93.529 |
# | ('mutect', 'varscan')                          |    543 |         0.000 |     706 |          0.000 |          79.853 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -4.746 |     0.219 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -0.192 |     0.179 |   3.488 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -2.731 |    -0.305 |   1.314 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   2.916 |
# +------------------------------------------------+----------+-----------+---------+
# HNSC
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   5266 |        16.970 |    6214 |          2.053 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   5188 |        15.238 |    6205 |          1.905 |          98.519 |
# | ('mutect', 'varscan', 'somaticsniper')         |   4898 |         8.796 |    6108 |          0.312 |          93.012 |
# | ('mutect', 'varscan')                          |   4502 |         0.000 |    6089 |          0.000 |          85.492 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    171 |        11.039 |     199 |          2.577 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    170 |        10.390 |     199 |          2.577 |          99.415 |
# | ('mutect', 'varscan', 'somaticsniper')         |    160 |         3.896 |     194 |          0.000 |          93.567 |
# | ('mutect', 'varscan')                          |    154 |         0.000 |     194 |          0.000 |          90.058 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -5.931 |     0.524 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -4.848 |     0.672 |   0.896 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -4.900 |    -0.312 |   0.555 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   4.567 |
# +------------------------------------------------+----------+-----------+---------+
# KICH
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    133 |        27.885 |     195 |          3.723 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |    125 |        20.192 |     194 |          3.191 |          93.985 |
# | ('mutect', 'varscan', 'muse')                  |    125 |        20.192 |     189 |          0.532 |          93.985 |
# | ('mutect', 'varscan')                          |    104 |         0.000 |     188 |          0.000 |          78.195 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |     39 |        25.806 |      44 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |     36 |        16.129 |      44 |          0.000 |          92.308 |
# | ('mutect', 'varscan', 'muse')                  |     36 |        16.129 |      44 |          0.000 |          92.308 |
# | ('mutect', 'varscan')                          |     31 |         0.000 |      44 |          0.000 |          79.487 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -2.078 |    -3.723 |   0.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -4.063 |    -3.191 |  -1.677 |
# | ('mutect', 'varscan', 'muse')                  |   -4.063 |    -0.532 |  -1.677 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   1.292 |
# +------------------------------------------------+----------+-----------+---------+
# KIRC
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   1448 |        14.106 |    1841 |          1.825 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1419 |        11.820 |    1831 |          1.272 |          97.997 |
# | ('mutect', 'varscan', 'somaticsniper')         |   1352 |         6.541 |    1820 |          0.664 |          93.370 |
# | ('mutect', 'varscan')                          |   1269 |         0.000 |    1808 |          0.000 |          87.638 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan')                          |      3 |         0.000 |     108 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |      3 |         0.000 |     108 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |      3 |         0.000 |     108 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |      3 |         0.000 |     108 |          0.000 |         100.000 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |  -14.106 |    -1.825 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |  -11.820 |    -1.272 |   2.003 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -6.541 |    -0.664 |   6.630 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |  12.362 |
# +------------------------------------------------+----------+-----------+---------+
# KIRP
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   1071 |        14.914 |    1293 |          3.440 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1042 |        11.803 |    1275 |          2.000 |          97.292 |
# | ('mutect', 'varscan', 'somaticsniper')         |   1026 |        10.086 |    1268 |          1.440 |          95.798 |
# | ('mutect', 'varscan')                          |    932 |         0.000 |    1250 |          0.000 |          87.021 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper')         |     12 |         9.091 |      13 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |     12 |         9.091 |      13 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |     12 |         9.091 |      13 |          0.000 |         100.000 |
# | ('mutect', 'varscan')                          |     11 |         0.000 |      13 |          0.000 |          91.667 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -5.823 |    -3.440 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -2.712 |    -2.000 |   2.708 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -0.995 |    -1.440 |   4.202 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   4.645 |
# +------------------------------------------------+----------+-----------+---------+
# LAML
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    311 |        85.119 |     699 |          8.879 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |    257 |        52.976 |     691 |          7.632 |          82.637 |
# | ('mutect', 'varscan', 'muse')                  |    242 |        44.048 |     652 |          1.558 |          77.814 |
# | ('mutect', 'varscan')                          |    168 |         0.000 |     642 |          0.000 |          54.019 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |     35 |        84.211 |      91 |          2.247 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |     30 |        57.895 |      90 |          1.124 |          85.714 |
# | ('mutect', 'varscan', 'somaticsniper')         |     25 |        31.579 |      90 |          1.124 |          71.429 |
# | ('mutect', 'varscan')                          |     19 |         0.000 |      89 |          0.000 |          54.286 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -0.909 |    -6.631 |   0.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |    4.919 |    -6.509 |   3.078 |
# | ('mutect', 'varscan', 'muse')                  |  -12.469 |    -0.434 |  -6.385 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   0.266 |
# +------------------------------------------------+----------+-----------+---------+
# LGG
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   2561 |        28.178 |    3274 |          1.930 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2478 |        24.024 |    3269 |          1.775 |          96.759 |
# | ('mutect', 'varscan', 'somaticsniper')         |   2366 |        18.418 |    3222 |          0.311 |          92.386 |
# | ('mutect', 'varscan')                          |   1998 |         0.000 |    3212 |          0.000 |          78.016 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    594 |        33.184 |     702 |          2.332 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    589 |        32.063 |     702 |          2.332 |          99.158 |
# | ('mutect', 'varscan', 'somaticsniper')         |    531 |        19.058 |     686 |          0.000 |          89.394 |
# | ('mutect', 'varscan')                          |    446 |         0.000 |     686 |          0.000 |          75.084 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    5.006 |     0.402 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |    8.039 |     0.558 |   2.399 |
# | ('mutect', 'varscan', 'somaticsniper')         |    0.640 |    -0.311 |  -2.992 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |  -2.932 |
# +------------------------------------------------+----------+-----------+---------+
# LIHC
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   2402 |        16.039 |    2867 |          2.210 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   2342 |        13.140 |    2850 |          1.604 |          97.502 |
# | ('mutect', 'varscan', 'somaticsniper')         |   2292 |        10.725 |    2826 |          0.749 |          95.420 |
# | ('mutect', 'varscan')                          |   2070 |         0.000 |    2805 |          0.000 |          86.178 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'muse')                  |     82 |        17.143 |      94 |          3.297 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |     82 |        17.143 |      94 |          3.297 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |     80 |        14.286 |      91 |          0.000 |          97.561 |
# | ('mutect', 'varscan')                          |     70 |         0.000 |      91 |          0.000 |          85.366 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    1.104 |     1.086 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |    4.003 |     1.692 |   2.498 |
# | ('mutect', 'varscan', 'somaticsniper')         |    3.561 |    -0.749 |   2.140 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |  -0.812 |
# +------------------------------------------------+----------+-----------+---------+
# LUAD
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   9302 |        21.214 |   11034 |          1.940 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   9069 |        18.178 |   10998 |          1.608 |          97.495 |
# | ('mutect', 'varscan', 'somaticsniper')         |   8492 |        10.659 |   10869 |          0.416 |          91.292 |
# | ('mutect', 'varscan')                          |   7674 |         0.000 |   10824 |          0.000 |          82.498 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    125 |        38.889 |     141 |          0.714 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    120 |        33.333 |     141 |          0.714 |          96.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |    113 |        25.556 |     140 |          0.000 |          90.400 |
# | ('mutect', 'varscan')                          |     90 |         0.000 |     140 |          0.000 |          72.000 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   17.674 |    -1.226 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   15.155 |    -0.893 |  -1.495 |
# | ('mutect', 'varscan', 'somaticsniper')         |   14.896 |    -0.416 |  -0.892 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 | -10.498 |
# +------------------------------------------------+----------+-----------+---------+
# LUSC
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   8284 |        18.343 |    9595 |          2.205 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   8088 |        15.543 |    9571 |          1.949 |          97.634 |
# | ('mutect', 'varscan', 'somaticsniper')         |   7698 |         9.971 |    9429 |          0.437 |          92.926 |
# | ('mutect', 'varscan')                          |   7000 |         0.000 |    9388 |          0.000 |          84.500 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    169 |        17.361 |     175 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    165 |        14.583 |     175 |          0.000 |          97.633 |
# | ('mutect', 'varscan', 'somaticsniper')         |    158 |         9.722 |     175 |          0.000 |          93.491 |
# | ('mutect', 'varscan')                          |    144 |         0.000 |     175 |          0.000 |          85.207 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -0.982 |    -2.205 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -0.960 |    -1.949 |  -0.001 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -0.249 |    -0.437 |   0.565 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   0.707 |
# +------------------------------------------------+----------+-----------+---------+
# MESO
# total
# ...
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    141 |        11.024 |     206 |          3.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    139 |         9.449 |     200 |          0.000 |          98.582 |
# | ('mutect', 'varscan', 'somaticsniper')         |    133 |         4.724 |     206 |          3.000 |          94.326 |
# | ('mutect', 'varscan')                          |    127 |         0.000 |     200 |          0.000 |          90.071 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan')                          |      3 |         0.000 |       3 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |      3 |         0.000 |       3 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |      3 |         0.000 |       3 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |      3 |         0.000 |       3 |          0.000 |         100.000 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |  -11.024 |    -3.000 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -9.449 |     0.000 |   1.418 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -4.724 |    -3.000 |   5.674 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   9.929 |
# +------------------------------------------------+----------+-----------+---------+
# THCA
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    622 |        10.088 |     886 |          1.489 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    614 |         8.673 |     886 |          1.489 |          98.714 |
# | ('mutect', 'varscan', 'somaticsniper')         |    597 |         5.664 |     873 |          0.000 |          95.981 |
# | ('mutect', 'varscan')                          |    565 |         0.000 |     873 |          0.000 |          90.836 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper')         |      1 |           inf |      34 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |      1 |           inf |      34 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |      1 |           inf |      34 |          0.000 |         100.000 |
# | ('mutect', 'varscan')                          |      0 |           nan |      34 |          0.000 |           0.000 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |      inf |    -1.489 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |      inf |    -1.489 |   1.286 |
# | ('mutect', 'varscan', 'somaticsniper')         |      inf |     0.000 |   4.019 |
# | ('mutect', 'varscan')                          |      nan |     0.000 | -90.836 |
# +------------------------------------------------+----------+-----------+---------+
# THYM
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    132 |        15.789 |     198 |          3.665 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    128 |        12.281 |     194 |          1.571 |          96.970 |
# | ('mutect', 'varscan', 'somaticsniper')         |    125 |         9.649 |     196 |          2.618 |          94.697 |
# | ('mutect', 'varscan')                          |    114 |         0.000 |     191 |          0.000 |          86.364 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper')         |     34 |         9.677 |      38 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |     34 |         9.677 |      38 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |     34 |         9.677 |      38 |          0.000 |         100.000 |
# | ('mutect', 'varscan')                          |     31 |         0.000 |      38 |          0.000 |          91.176 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -6.112 |    -3.665 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -2.603 |    -1.571 |   3.030 |
# | ('mutect', 'varscan', 'somaticsniper')         |    0.028 |    -2.618 |   5.303 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   4.813 |
# +------------------------------------------------+----------+-----------+---------+
# UCEC
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |  33242 |        19.662 |   38136 |          2.329 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |  32798 |        18.063 |   38065 |          2.139 |          98.664 |
# | ('mutect', 'varscan', 'somaticsniper')         |  31671 |        14.006 |   37374 |          0.284 |          95.274 |
# | ('mutect', 'varscan')                          |  27780 |         0.000 |   37268 |          0.000 |          83.569 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   1493 |        40.188 |    1610 |          3.938 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |   1483 |        39.249 |    1608 |          3.809 |          99.330 |
# | ('mutect', 'varscan', 'somaticsniper')         |   1376 |        29.202 |    1551 |          0.129 |          92.163 |
# | ('mutect', 'varscan')                          |   1065 |         0.000 |    1549 |          0.000 |          71.333 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   20.526 |     1.609 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   21.185 |     1.670 |   0.666 |
# | ('mutect', 'varscan', 'somaticsniper')         |   15.195 |    -0.155 |  -3.111 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 | -12.236 |
# +------------------------------------------------+----------+-----------+---------+
# UCS
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    653 |        34.086 |     782 |          1.956 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    620 |        27.310 |     777 |          1.304 |          94.946 |
# | ('mutect', 'varscan', 'somaticsniper')         |    608 |        24.846 |     777 |          1.304 |          93.109 |
# | ('mutect', 'varscan')                          |    487 |         0.000 |     767 |          0.000 |          74.579 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    247 |        13.825 |     257 |          0.784 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    245 |        12.903 |     256 |          0.392 |          99.190 |
# | ('mutect', 'varscan', 'somaticsniper')         |    238 |         9.677 |     256 |          0.392 |          96.356 |
# | ('mutect', 'varscan')                          |    217 |         0.000 |     255 |          0.000 |          87.854 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |  -20.261 |    -1.171 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |  -14.407 |    -0.912 |   4.244 |
# | ('mutect', 'varscan', 'somaticsniper')         |  -15.169 |    -0.912 |   3.248 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |  13.275 |
# +------------------------------------------------+----------+-----------+---------+
# UVM
# total
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |    199 |        25.949 |     257 |          2.390 |         100.000 |
# | ('mutect', 'varscan', 'muse')                  |    187 |        18.354 |     254 |          1.195 |          93.970 |
# | ('mutect', 'varscan', 'somaticsniper')         |    185 |        17.089 |     257 |          2.390 |          92.965 |
# | ('mutect', 'varscan')                          |    158 |         0.000 |     251 |          0.000 |          79.397 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# outlier
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
# | variant callers                                |   real |   real % diff |   total |   total % diff |   % of all real |
# |------------------------------------------------+--------+---------------+---------+----------------+-----------------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |     18 |        20.000 |      22 |          0.000 |         100.000 |
# | ('mutect', 'varscan', 'somaticsniper')         |     17 |        13.333 |      22 |          0.000 |          94.444 |
# | ('mutect', 'varscan', 'muse')                  |     17 |        13.333 |      22 |          0.000 |          94.444 |
# | ('mutect', 'varscan')                          |     15 |         0.000 |      22 |          0.000 |          83.333 |
# +------------------------------------------------+--------+---------------+---------+----------------+-----------------+
#
# difference between total and outlier
# +------------------------------------------------+----------+-----------+---------+
# | variant callers                                |   real % |   total % |   % all |
# |------------------------------------------------+----------+-----------+---------|
# | ('mutect', 'varscan', 'somaticsniper', 'muse') |   -5.949 |    -2.390 |   0.000 |
# | ('mutect', 'varscan', 'muse')                  |   -5.021 |    -1.195 |   0.475 |
# | ('mutect', 'varscan', 'somaticsniper')         |   -3.755 |    -2.390 |   1.480 |
# | ('mutect', 'varscan')                          |    0.000 |     0.000 |   3.936 |
# +------------------------------------------------+----------+-----------+---------+
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:73: RuntimeWarning: invalid value encountered in long_scalars
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:73: RuntimeWarning: divide by zero encountered in long_scalars

# %%
sort = sorted(dictofout.items(), key=itemgetter(1), reverse = True)
for i in range(len(sort)):
    print(sort[i])
# Out:
# ('SKCM', 58.14547801792173)
# ('THCA', nan)
# ('UCEC', 56.90703616950081)
# ('UCS', 49.83676984074414)
# ('MESO', 47.773279352226716)
# ('LUAD', 47.725653722526275)
# ('OV', 47.72277227722772)
# ('COAD', 44.60888982414428)
# ('ACC', 39.55414918580673)
# ('SARC', 34.083400160384926)
# ('KIRC', 32.46650906225374)
# ('PCPG', 28.57142857142857)
# ('STAD', 26.583346444304595)
# ('TGCT', 25.196850393700785)
# ('DLBC', 21.862885125484596)
# ('LAML', 18.29573934837094)
# ('HNSC', 15.679322898336668)
# ('BRCA', 15.619486733362326)
# ('UVM', 14.725738396624472)
# ('LGG', 13.684312114805387)
# ('PRAD', 11.764433633825128)
# ('KICH', 10.204714640198517)
# ('CESC', 10.03248755657091)
# ('KIRP', 9.52984783456886)
# ('THYM', 8.743633276740237)
# ('LIHC', 8.66804692891649)
# ('GBM', 7.669500933871447)
# ('CHOL', 6.0971524288107215)
# ('PAAD', 4.859294662452683)
# ('ESCA', 4.645962108648677)
# ('BLCA', 4.6028699387624545)
# ('READ', 4.135338345864666)
# ('LUSC', 2.19047619047619)

# %%
print(dfcgc)
# Out:
#                                         ACC  BLCA  BRCA  CESC  CHOL   COAD  \
# (muse)                                    5   232   159   167     7    150
# (mutect)                                 47   855  1066   440    44   1373
# (somaticsniper)                          16    26    75    26     3     46
# (varscan)                                75   285   366   137    28    767
# (mutect, muse)                           27   383   363   126     4    485
# (muse, somaticsniper)                     4    16     7     8     1     15
# (muse, varscan)                           5   112    64    60     4    179
# (mutect, somaticsniper)                   0    65    18    17     4     21
# (mutect, varscan)                        43   580   879   264    47   1834
# (varscan, somaticsniper)                 43    71    70    39     3    155
# (mutect, muse, somaticsniper)            26   150    89    37     8    117
# (mutect, muse, varscan)                  27   778   761   254    11   1277
# (muse, somaticsniper, varscan)           39   458   212   284    13    753
# (mutect, varscan, somaticsniper)          3   109   118    82     7    126
# (mutect, muse, somaticsniper, varscan)  270  4264  2992  2554   134   6134
# Total                                   630  8384  7239  4495   318  13432
#
#                                         DLBC  ESCA   GBM  HNSC ...   READ  \
# (muse)                                    23    28    66   106 ...     49
# (mutect)                                  43   222  1589   642 ...    306
# (somaticsniper)                            4    27    11     9 ...     10
# (varscan)                                 42   123   206   191 ...    149
# (mutect, muse)                            20    55   134   268 ...    137
# (muse, somaticsniper)                      2    11    22    10 ...      4
# (muse, varscan)                            4    21    58    90 ...     43
# (mutect, somaticsniper)                    2    19    10    21 ...     12
# (mutect, varscan)                         27   246   212   577 ...    260
# (varscan, somaticsniper)                  20    27    76    47 ...     46
# (mutect, muse, somaticsniper)             12    47    72    70 ...     58
# (mutect, muse, varscan)                   34   126   304   738 ...    275
# (muse, somaticsniper, varscan)            59    91   262   258 ...    266
# (mutect, varscan, somaticsniper)           4    59    41    94 ...     45
# (mutect, muse, somaticsniper, varscan)   273  1043  1558  3093 ...   1852
# Total                                    569  2145  4621  6214 ...   3512
#
#                                         SARC   SKCM   STAD  TGCT  THCA  THYM  \
# (muse)                                    18    213    106     0    13     2
# (mutect)                                 191    851   1213    29   241    45
# (somaticsniper)                           30     24     18     6     0     4
# (varscan)                                123    490    563    30    10    15
# (mutect, muse)                            27    548    490     7    19     5
# (muse, somaticsniper)                      4     35      8     0     0     1
# (muse, varscan)                           22    312    124     1     6     1
# (mutect, somaticsniper)                   22    143     39     0     3     0
# (mutect, varscan)                        119    622   1963    20    42    19
# (varscan, somaticsniper)                  14    157     65     2     5     3
# (mutect, muse, somaticsniper)             35    286     74     1     3     1
# (mutect, muse, varscan)                   61   1280   1129    23    16    10
# (muse, somaticsniper, varscan)            54   1271    520     3    21     7
# (mutect, varscan, somaticsniper)          20    259    136     0    15     6
# (mutect, muse, somaticsniper, varscan)   525  10497   4717    84   492    79
# Total                                   1265  16988  11165   206   886   198
#
#                                          UCEC  UCS  UVM
# (muse)                                    762    5    0
# (mutect)                                 3019   66   38
# (somaticsniper)                            71    5    3
# (varscan)                                1042   53   17
# (mutect, muse)                           1131   22    5
# (muse, somaticsniper)                      35    5    3
# (muse, varscan)                           405   18    6
# (mutect, somaticsniper)                    88   14    6
# (mutect, varscan)                        2947   57    7
# (varscan, somaticsniper)                  321   14    3
# (mutect, muse, somaticsniper)             170   27    4
# (mutect, muse, varscan)                  2085   31    3
# (muse, somaticsniper, varscan)           3312   66   14
# (mutect, varscan, somaticsniper)          495    7    0
# (mutect, muse, somaticsniper, varscan)  22253  392  148
# Total                                   38136  782  257
#
# [16 rows x 33 columns]

# %%
import os, sys, argparse
from upsetplot import from_memberships
from upsetplot import plot
# %matplotlib inline 
from matplotlib import pyplot
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd

original = os.getcwd()

possible_callers = ('muse', 'mutect', 'somaticsniper', 'varscan')

possible_cancers = ('ACC', 'BLCA','BRCA','CESC','CHOL','COAD','DLBC','ESCA','GBM','HNSC', 
					'KICH','KIRC','KIRP','LAML','LGG','LIHC','LUAD','LUSC','MESO', 'OV','PAAD',
                    'PCPG','PRAD','READ','SARC','SKCM','STAD','TGCT','THCA','THYM','UCEC','UCS','UVM')

from itertools import combinations

# combine these two functions into one (maybe just rename first one keys?)

def my_combs(iterable, r):
    to_return = []
    for i in range(1, r+1):
        c = combinations(iterable, i)
        for comb in c:
            if len(comb) == 1:
                to_return.extend((comb,))
            else:
                to_return.append(list(comb))
    return to_return

def intersections(list_of_sets):
    '''
    Given a list of sets, returns all possible exclusive intersections of the sets.
    '''
    sets = list_of_sets
    combs = []
    inters = []
    ret = []

    for i in range(len(sets)):
        combs.append(my_combs(range(len(sets)), abs(len(sets)-i)))
        inter = []
        for comb in combs[i]:
            intersect = sets[comb[0]]
            for j in range(len(comb)):
                intersect = intersect & sets[comb[j]]
            for j in range(i):
                for comb2, inter2 in zip(combs[j], inters[j]):
                    condition = True
                    for k in range(len(comb)):
                        condition = condition and (comb[k] in comb2)
                    if condition is True:
                        intersect -= inter2
            inter.append(intersect)
        inters.append(inter)
    
    for j in range(len(sets)):
        ret.extend(inters[len(sets)-1-j])
    
    return ret

def n_intersections(sets, nways):
    combs = my_combs(sets, nways)
    inters = []
    for c in range(len(combs)):
        inters.append(intersections(combs[c]))
    return inters

# %%
def parse_maf(fp):
    ''' Return a dictionary with vars[patient][variant_set]'''
    caller_vars = {}

    fh = open(fp, 'r')
    for line in fh:
        temp = line.strip().split('\t')
        if line[0] == '#' or temp[0] == 'Hugo_Symbol':
            continue
        ID = temp[16] + '_' + temp[17] # 'tumor'_'normal'
        if ID not in caller_vars:
            caller_vars[ID] = set()
        gene = temp[0]
        chrom =temp[4]
        s_pos = temp[5]
        e_pos = temp[6]
        ref = temp[11]
        tum_allele_1 = temp[12]
        tum_allele_2 = temp[13]
        impact = temp[93]
        filt = temp[110]
        var = (gene,chrom, s_pos, e_pos, ref, tum_allele_1, tum_allele_2,impact, filt)
        caller_vars[ID].add(var)

    return(caller_vars)

# %%
keys = my_combs_frozenset(possible_callers, len(possible_callers))

def set_contents(dat, possible_callers):        
    data = dict([(key, []) for key in keys])
    
    patients = set(list(dat[0].keys()))
    for i in range(len(dat)):
        patients = patients & set(list(dat[i].keys()))
    
    
    for patient in patients:
        sets = []
        for j in range(len(dat)):
            sets.append(dat[j][patient])
        
        inters = intersections(sets)
        
        for i in range(len(inters)):
            data[keys[i]].extend(list(inters[i]))
       
    return data

# %%
os.chdir(original)
possible_cancers = ('ACC', 'BLCA','BRCA','CESC','CHOL','COAD', 'DLBC','ESCA','GBM','HNSC', 
					'KICH','KIRC','KIRP','LAML','LGG','LIHC','LUAD','LUSC','MESO', 'OV','PAAD',
                    'PCPG','PRAD','READ','SARC','SKCM','STAD','TGCT','THCA','THYM','UCEC','UCS','UVM')

g = np.array(np.genfromtxt('Bailey_et_al_2018_sig_mut_genes.txt',dtype=None,encoding = None, usecols = (0)))
c = np.genfromtxt('Bailey_et_al_2018_sig_mut_genes.txt',dtype=None,encoding = None, usecols = (1))
genes = np.delete(g,4)
cancers = np.delete(c,4)
dictofgenes = dict([(cancer, set()) for cancer in cancers])

for i in range(len(genes)):
    dictofgenes[cancers[i]].add(genes[i])

pancandict = dictofgenes['PANCAN']
coadread = dictofgenes['COADREAD']

del dictofgenes['PANCAN']
del dictofgenes['COADREAD']

impacts = set(('MODERATE', 'HIGH'))
filt = set(('PASS'))

def how_many_tumor(cancer, all_variants, possible_callers, content):
    if cancer == 'COAD' or cancer == 'READ':
        tumorcount = []
        for key in keys:
            count = 0
            for c in content[key]:
                if set(c) & coadread:
                    if set(c) & impacts:
                        if 'PASS' in set(c):
                            count += 1
            tumorcount.append(count)
    else:
        tumorcount = []
        for key in keys:
            count = 0
            for c in content[key]:
                if set(c) & dictofgenes[cancer]:
                    if set(c) & impacts:
                        if 'PASS' in set(c):
                            count += 1
            tumorcount.append(count)
    return tumorcount

# %%
def baileydf(possible_cancers, possible_callers):
    dfbailey = pd.DataFrame(np.nan, index=keys, columns=possible_cancers)

    for cancer in possible_cancers:
        os.chdir(original)
        os.chdir(cancer)
        mafs = os.listdir()

        maf_fps = {}
        for caller in possible_callers:
            for maf in mafs:
                if caller in maf: # str in the filepath
                    maf_fps[caller] = maf

        all_variants = {}
    
        for caller in maf_fps:
            all_variants[caller] = parse_maf(maf_fps[caller])
        arg = []
        for i in range(len(possible_callers)):
            arg.append(all_variants[possible_callers[i]])

        content = set_contents(arg, possible_callers)
        dfbailey.loc[:,cancer] = how_many_tumor(cancer, all_variants, possible_callers, content)
    return dfbailey
dfbailey = baileydf(possible_cancers, possible_callers)
print(dfbailey)
# Out:
#                                         ACC  BLCA  BRCA  CESC  CHOL  COAD  \
# (muse)                                    0    78    34    24     3    18
# (mutect)                                  4   223   184    53     5    88
# (somaticsniper)                           0    10     5     1     0     4
# (varscan)                                14   178   145    34     2   165
# (mutect, muse)                            3    86    44    27     1    45
# (muse, somaticsniper)                     0     8     2     2     0     3
# (varscan, muse)                           0    51    11    11     2    11
# (mutect, somaticsniper)                   0    37     5     6     2     5
# (mutect, varscan)                        12   314   512    58    17   347
# (varscan, somaticsniper)                  7    34    35    14     0    47
# (mutect, muse, somaticsniper)             7    79    50    20     0    64
# (mutect, varscan, muse)                   0   116    81    32     0    92
# (varscan, muse, somaticsniper)            3   165    64    44     1   117
# (mutect, varscan, somaticsniper)          0    33    34    14     1    14
# (mutect, varscan, muse, somaticsniper)   17  1073   882   393    14   874
#
#                                         DLBC  ESCA  GBM  HNSC ...   READ  \
# (muse)                                    17     7   16    26 ...      6
# (mutect)                                   2    29  108   148 ...     25
# (somaticsniper)                            0     1    4     3 ...      1
# (varscan)                                 18    40  105   118 ...     50
# (mutect, muse)                             7     2   49    54 ...     21
# (muse, somaticsniper)                      2     5   12     4 ...      1
# (varscan, muse)                            1     6    9    31 ...      7
# (mutect, somaticsniper)                    0     8    4    11 ...      3
# (mutect, varscan)                         12    71   95   298 ...    101
# (varscan, somaticsniper)                   5     6   36    21 ...     18
# (mutect, muse, somaticsniper)              5    21   44    41 ...     30
# (mutect, varscan, muse)                    2     8   37   106 ...     15
# (varscan, muse, somaticsniper)            36    28   72    97 ...     48
# (mutect, varscan, somaticsniper)           3    11    4    45 ...     14
# (mutect, varscan, muse, somaticsniper)    48   167  350   807 ...    315
#
#                                         SARC  SKCM  STAD  TGCT  THCA  THYM  \
# (muse)                                     1    21    10     0     0     0
# (mutect)                                  27    79   115     5    13     4
# (somaticsniper)                            1     3     3     1     0     0
# (varscan)                                 34    94   103     1     2     1
# (mutect, muse)                             1    41    39     0     1    18
# (muse, somaticsniper)                      0     7     1     0     0     0
# (varscan, muse)                           13    23    21     0     0     0
# (mutect, somaticsniper)                   15    20    13     0     0     0
# (mutect, varscan)                         32    71   293     1     9     1
# (varscan, somaticsniper)                   3    33     6     0     4     2
# (mutect, muse, somaticsniper)             13    57    22     1     2     0
# (mutect, varscan, muse)                    1    81    82     9     0    15
# (varscan, muse, somaticsniper)            19    95    57     1     6     1
# (mutect, varscan, somaticsniper)           2    28    18     0    10     2
# (mutect, varscan, muse, somaticsniper)    53   864   535    22   336    35
#
#                                         UCEC  UCS  UVM
# (muse)                                   104    2    0
# (mutect)                                 445   29   22
# (somaticsniper)                            8    4    2
# (varscan)                                453   28   10
# (mutect, muse)                           191    3    1
# (muse, somaticsniper)                     13    4    0
# (varscan, muse)                           75   15    3
# (mutect, somaticsniper)                   31   10    4
# (mutect, varscan)                       1038   21    3
# (varscan, somaticsniper)                  94    6    2
# (mutect, muse, somaticsniper)             90   17    2
# (mutect, varscan, muse)                  258    7    0
# (varscan, muse, somaticsniper)           548   26    6
# (mutect, varscan, somaticsniper)          76    3    0
# (mutect, varscan, muse, somaticsniper)  3881   87  104
#
# [15 rows x 33 columns]

# %%
def table(df, callers, additional_callers, cancer):
    #df = baileydf(possible_cancers, callers)
    
    sets = []
    sets.append(list(callers))
    ad = my_combs(additional_callers, len(additional_callers))

    for n in range(len(ad)):
        sets.append(callers+list(ad[n]))

    for i in range(len(sets)):
        sets[i] = tuple(sets[i])

    sums = pd.DataFrame(0, index=sets, columns=('real', 'real %', 'total', 'total %'))

    su = []
    for i in range(len(sets)):
        index = []
        for j in range(len(keys)):
            if len(set(sets[i])&keys[j]) >= 2:
                index.append(j)
        s =[]
        for k in range(len(index)):
            s.append(df[cancer][index[k]])
        su.append(np.sum(s))
    sums.loc[:,'real'] = su
    
    tot = []
    for i in range(len(sets)):
        index = []
        for j in range(len(keys)):
            if len(set(sets[i])&keys[j]) >= 1:
                index.append(j)        
        t =[]
        for k in range(len(index)):
            t.append(df[cancer][index[k]])
        tot.append(np.sum(t))
    sums.loc[:,'total'] = tot
    
    rpercent = [0]
    for i in range(1, len(sets)):
        rpercent.append((sums['real'][i] - sums['real'][0]) / sums['real'][0])
    sums.loc[:,'real %'] = rpercent
    
    tpercent = [0]
    for i in range(1, len(sets)):
        tpercent.append((sums['total'][i] - sums['total'][0]) / sums['total'][0])
    sums.loc[:,'total %'] = tpercent
    sums = sums.sort_values(['real %'], ascending=False)
    return sums

from tabulate import tabulate
callers = ['mutect', 'varscan']
additional_callers = ['muse', 'somaticsniper']
for cancer in possible_cancers:
    print(cancer)
    df = table(dfbailey, callers, additional_callers,cancer)
    print(tabulate(df, headers='keys', tablefmt='psql'))
    print()
# Out:
# ACC
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |     49 | 0.689655 |      67 |         0 |
# | ('mutect', 'varscan', 'somaticsniper')         |     46 | 0.586207 |      67 |         0 |
# | ('mutect', 'varscan', 'muse')                  |     42 | 0.448276 |      67 |         0 |
# | ('mutect', 'varscan')                          |     29 | 0        |      67 |         0 |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# BLCA
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1996 | 0.299479 |    2485 | 0.0401842  |
# | ('mutect', 'varscan', 'muse')                  |   1917 | 0.248047 |    2475 | 0.0359983  |
# | ('mutect', 'varscan', 'somaticsniper')         |   1851 | 0.205078 |    2407 | 0.00753453 |
# | ('mutect', 'varscan')                          |   1536 | 0        |    2389 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# BRCA
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1720 | 0.139828 |    2088 | 0.0200293  |
# | ('mutect', 'varscan', 'muse')                  |   1678 | 0.111995 |    2083 | 0.0175867  |
# | ('mutect', 'varscan', 'somaticsniper')         |   1663 | 0.102054 |    2054 | 0.00341964 |
# | ('mutect', 'varscan')                          |   1509 | 0        |    2047 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# CESC
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    621 | 0.249497 |     733 | 0.0382436  |
# | ('mutect', 'varscan', 'muse')                  |    599 | 0.205231 |     732 | 0.0368272  |
# | ('mutect', 'varscan', 'somaticsniper')         |    581 | 0.169014 |     709 | 0.00424929 |
# | ('mutect', 'varscan')                          |    497 | 0        |     706 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# CHOL
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |     38 |  0.1875  |      48 | 0.0666667 |
# | ('mutect', 'varscan', 'muse')                  |     36 |  0.125   |      48 | 0.0666667 |
# | ('mutect', 'varscan', 'somaticsniper')         |     35 |  0.09375 |      45 | 0         |
# | ('mutect', 'varscan')                          |     32 |  0       |      45 | 0         |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# COAD
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1619 | 0.220045 |    1894 | 0.0133761  |
# | ('mutect', 'varscan', 'muse')                  |   1564 | 0.178598 |    1890 | 0.011236   |
# | ('mutect', 'varscan', 'somaticsniper')         |   1560 | 0.175584 |    1876 | 0.00374532 |
# | ('mutect', 'varscan')                          |   1327 | 0        |    1869 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# DLBC
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    121 | 0.861538 |     158 | 0.136691  |
# | ('mutect', 'varscan', 'muse')                  |    114 | 0.753846 |     158 | 0.136691  |
# | ('mutect', 'varscan', 'somaticsniper')         |    111 | 0.707692 |     141 | 0.0143885 |
# | ('mutect', 'varscan')                          |     65 | 0        |     139 | 0         |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# ESCA
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    333 | 0.29572  |     410 | 0.0327456 |
# | ('mutect', 'varscan', 'somaticsniper')         |    320 | 0.245136 |     403 | 0.0151134 |
# | ('mutect', 'varscan', 'muse')                  |    314 | 0.22179  |     409 | 0.0302267 |
# | ('mutect', 'varscan')                          |    257 | 0        |     397 | 0         |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# GBM
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    712 | 0.465021 |     945 | 0.0350493 |
# | ('mutect', 'varscan', 'muse')                  |    660 | 0.358025 |     941 | 0.0306681 |
# | ('mutect', 'varscan', 'somaticsniper')         |    642 | 0.320988 |     929 | 0.0175246 |
# | ('mutect', 'varscan')                          |    486 | 0        |     913 | 0         |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# HNSC
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1515 | 0.20621  |    1810 | 0.0185706  |
# | ('mutect', 'varscan', 'muse')                  |   1479 | 0.177548 |    1807 | 0.0168824  |
# | ('mutect', 'varscan', 'somaticsniper')         |   1426 | 0.13535  |    1784 | 0.00393922 |
# | ('mutect', 'varscan')                          |   1256 | 0        |    1777 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# KICH
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |     25 | 0.785714 |      38 |         0 |
# | ('mutect', 'varscan', 'muse')                  |     23 | 0.642857 |      38 |         0 |
# | ('mutect', 'varscan', 'somaticsniper')         |     23 | 0.642857 |      38 |         0 |
# | ('mutect', 'varscan')                          |     14 | 0        |      38 |         0 |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# KIRC
# +------------------------------------------------+--------+-----------+---------+------------+
# |                                                |   real |    real % |   total |    total % |
# |------------------------------------------------+--------+-----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    443 | 0.0992556 |     532 | 0.00948767 |
# | ('mutect', 'varscan', 'somaticsniper')         |    433 | 0.0744417 |     527 | 0          |
# | ('mutect', 'varscan', 'muse')                  |    431 | 0.0694789 |     532 | 0.00948767 |
# | ('mutect', 'varscan')                          |    403 | 0         |     527 | 0          |
# +------------------------------------------------+--------+-----------+---------+------------+
#
# KIRP
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |     89 | 0.171053 |     127 | 0.0325203  |
# | ('mutect', 'varscan', 'somaticsniper')         |     87 | 0.144737 |     126 | 0.0243902  |
# | ('mutect', 'varscan', 'muse')                  |     84 | 0.105263 |     124 | 0.00813008 |
# | ('mutect', 'varscan')                          |     76 | 0        |     123 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# LAML
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    119 | 0.859375 |     197 | 0.158824  |
# | ('mutect', 'varscan', 'somaticsniper')         |    116 | 0.8125   |     195 | 0.147059  |
# | ('mutect', 'varscan', 'muse')                  |     78 | 0.21875  |     173 | 0.0176471 |
# | ('mutect', 'varscan')                          |     64 | 0        |     170 | 0         |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# LGG
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1340 | 0.29845  |    1734 | 0.0158172  |
# | ('mutect', 'varscan', 'muse')                  |   1271 | 0.231589 |    1733 | 0.0152314  |
# | ('mutect', 'varscan', 'somaticsniper')         |   1259 | 0.219961 |    1713 | 0.00351494 |
# | ('mutect', 'varscan')                          |   1032 | 0        |    1707 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# LIHC
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    584 | 0.179798 |     731 | 0.0266854  |
# | ('mutect', 'varscan', 'muse')                  |    568 | 0.147475 |     728 | 0.0224719  |
# | ('mutect', 'varscan', 'somaticsniper')         |    560 | 0.131313 |     718 | 0.00842697 |
# | ('mutect', 'varscan')                          |    495 | 0        |     712 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# LUAD
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1157 | 0.240086 |    1379 | 0.0268057 |
# | ('mutect', 'varscan', 'muse')                  |   1108 | 0.187567 |    1367 | 0.0178704 |
# | ('mutect', 'varscan', 'somaticsniper')         |   1100 | 0.178992 |    1357 | 0.0104244 |
# | ('mutect', 'varscan')                          |    933 | 0        |    1343 | 0         |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# LUSC
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1254 | 0.211594 |    1505 | 0.0294118  |
# | ('mutect', 'varscan', 'muse')                  |   1206 | 0.165217 |    1499 | 0.0253078  |
# | ('mutect', 'varscan', 'somaticsniper')         |   1191 | 0.150725 |    1474 | 0.00820793 |
# | ('mutect', 'varscan')                          |   1035 | 0        |    1462 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# MESO
# +------------------------------------------------+--------+-----------+---------+-----------+
# |                                                |   real |    real % |   total |   total % |
# |------------------------------------------------+--------+-----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |     65 | 0.140351  |      78 |         0 |
# | ('mutect', 'varscan', 'somaticsniper')         |     64 | 0.122807  |      78 |         0 |
# | ('mutect', 'varscan', 'muse')                  |     61 | 0.0701754 |      78 |         0 |
# | ('mutect', 'varscan')                          |     57 | 0         |      78 |         0 |
# +------------------------------------------------+--------+-----------+---------+-----------+
#
# OV
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    517 | 1.05976  |     726 | 0.03125   |
# | ('mutect', 'varscan', 'somaticsniper')         |    446 | 0.776892 |     712 | 0.0113636 |
# | ('mutect', 'varscan', 'muse')                  |    429 | 0.709163 |     724 | 0.0284091 |
# | ('mutect', 'varscan')                          |    251 | 0        |     704 | 0         |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# PAAD
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    273 | 0.263889 |     343 | 0.0425532  |
# | ('mutect', 'varscan', 'muse')                  |    269 | 0.24537  |     341 | 0.0364742  |
# | ('mutect', 'varscan', 'somaticsniper')         |    242 | 0.12037  |     332 | 0.00911854 |
# | ('mutect', 'varscan')                          |    216 | 0        |     329 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# PCPG
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |     50 | 0.190476 |      64 |  0.015873 |
# | ('mutect', 'varscan', 'muse')                  |     49 | 0.166667 |      64 |  0.015873 |
# | ('mutect', 'varscan', 'somaticsniper')         |     49 | 0.166667 |      63 |  0        |
# | ('mutect', 'varscan')                          |     42 | 0        |      63 |  0        |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# PRAD
# +------------------------------------------------+--------+-----------+---------+------------+
# |                                                |   real |    real % |   total |    total % |
# |------------------------------------------------+--------+-----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    242 | 0.146919  |     311 | 0.0264026  |
# | ('mutect', 'varscan', 'muse')                  |    232 | 0.0995261 |     310 | 0.0231023  |
# | ('mutect', 'varscan', 'somaticsniper')         |    232 | 0.0995261 |     306 | 0.00990099 |
# | ('mutect', 'varscan')                          |    211 | 0         |     303 | 0          |
# +------------------------------------------------+--------+-----------+---------+------------+
#
# READ
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    573 | 0.28764  |     655 | 0.0123648  |
# | ('mutect', 'varscan', 'muse')                  |    551 | 0.238202 |     654 | 0.0108192  |
# | ('mutect', 'varscan', 'somaticsniper')         |    544 | 0.222472 |     649 | 0.00309119 |
# | ('mutect', 'varscan')                          |    445 | 0        |     647 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# SARC
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    152 | 0.727273 |     215 | 0.00938967 |
# | ('mutect', 'varscan', 'somaticsniper')         |    138 | 0.568182 |     214 | 0.00469484 |
# | ('mutect', 'varscan', 'muse')                  |    134 | 0.522727 |     214 | 0.00469484 |
# | ('mutect', 'varscan')                          |     88 | 0        |     213 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# SKCM
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1320 | 0.264368 |    1517 | 0.0208614  |
# | ('mutect', 'varscan', 'muse')                  |   1260 | 0.206897 |    1514 | 0.0188425  |
# | ('mutect', 'varscan', 'somaticsniper')         |   1249 | 0.19636  |    1496 | 0.00672948 |
# | ('mutect', 'varscan')                          |   1044 | 0        |    1486 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# STAD
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   1087 | 0.171336 |    1318 | 0.0107362  |
# | ('mutect', 'varscan', 'muse')                  |   1067 | 0.149784 |    1315 | 0.00843558 |
# | ('mutect', 'varscan', 'somaticsniper')         |   1026 | 0.105603 |    1308 | 0.00306748 |
# | ('mutect', 'varscan')                          |    928 | 0        |    1304 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# TGCT
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse')                  |     34 |   0.0625 |      40 |     0     |
# | ('mutect', 'varscan', 'somaticsniper')         |     34 |   0.0625 |      41 |     0.025 |
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |     34 |   0.0625 |      41 |     0.025 |
# | ('mutect', 'varscan')                          |     32 |   0      |      40 |     0     |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# THCA
# +------------------------------------------------+--------+-----------+---------+-----------+
# |                                                |   real |    real % |   total |   total % |
# |------------------------------------------------+--------+-----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    368 | 0.0366197 |     383 |         0 |
# | ('mutect', 'varscan', 'somaticsniper')         |    367 | 0.0338028 |     383 |         0 |
# | ('mutect', 'varscan', 'muse')                  |    364 | 0.0253521 |     383 |         0 |
# | ('mutect', 'varscan')                          |    355 | 0         |     383 |         0 |
# +------------------------------------------------+--------+-----------+---------+-----------+
#
# THYM
# +------------------------------------------------+--------+-----------+---------+-----------+
# |                                                |   real |    real % |   total |   total % |
# |------------------------------------------------+--------+-----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |     74 | 0.396226  |      79 |         0 |
# | ('mutect', 'varscan', 'muse')                  |     72 | 0.358491  |      79 |         0 |
# | ('mutect', 'varscan', 'somaticsniper')         |     56 | 0.0566038 |      79 |         0 |
# | ('mutect', 'varscan')                          |     53 | 0         |      79 |         0 |
# +------------------------------------------------+--------+-----------+---------+-----------+
#
# UCEC
# +------------------------------------------------+--------+----------+---------+------------+
# |                                                |   real |   real % |   total |    total % |
# |------------------------------------------------+--------+----------+---------+------------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |   6295 | 0.198363 |    7305 | 0.0174095  |
# | ('mutect', 'varscan', 'muse')                  |   6157 | 0.172092 |    7297 | 0.0162953  |
# | ('mutect', 'varscan', 'somaticsniper')         |   6016 | 0.14525  |    7201 | 0.00292479 |
# | ('mutect', 'varscan')                          |   5253 | 0        |    7180 | 0          |
# +------------------------------------------------+--------+----------+---------+------------+
#
# UCS
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    199 | 0.686441 |     262 | 0.0396825 |
# | ('mutect', 'varscan', 'muse')                  |    179 | 0.516949 |     258 | 0.0238095 |
# | ('mutect', 'varscan', 'somaticsniper')         |    177 | 0.5      |     260 | 0.031746  |
# | ('mutect', 'varscan')                          |    118 | 0        |     252 | 0         |
# +------------------------------------------------+--------+----------+---------+-----------+
#
# UVM
# +------------------------------------------------+--------+----------+---------+-----------+
# |                                                |   real |   real % |   total |   total % |
# |------------------------------------------------+--------+----------+---------+-----------|
# | ('mutect', 'varscan', 'muse', 'somaticsniper') |    125 | 0.168224 |     159 | 0.0127389 |
# | ('mutect', 'varscan', 'somaticsniper')         |    121 | 0.130841 |     159 | 0.0127389 |
# | ('mutect', 'varscan', 'muse')                  |    119 | 0.11215  |     157 | 0         |
# | ('mutect', 'varscan')                          |    107 | 0        |     157 | 0         |
# +------------------------------------------------+--------+----------+---------+-----------+

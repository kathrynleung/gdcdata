# %%
# plain text, tab-delimited, and have specific column names
"""
1. Use the "any two" / cardinality of 2 approach.
2. Only use variants with PASS in column 111 (index 110).
3. Filter any variant that has one or more (it's a semi-colon separated list) of the following values in column 117 (index 116).
    - common_in_exac
    - gdc_pon
    - ndp
    - NonExonic
    - bitgt
4. Create new MAF files for all cancer types and callers that contain only variants remaining after applying the above criteria.
"""
import os
import pandas as pd 

def parse_maf(fp):
    
    f = pd.read_csv(fp, sep='\\\\t')
    print(f)
    col = list(f.iloc[4])[0].split('\t')
    f = f.drop(index = [0,1,2,3,4])
    f.index = range(0, len(f))
    
    new_f = pd.DataFrame(0, index = f.index, columns = col)
     
    for i in f.index:
        new_f.iloc[i] = list(f.iloc[i])[0].split('\t')

    return new_f
""" 
def filt(df1, df2, df3, df4):
    
def corem(df1,df2, df3,df3):
"""

possible_callers = ('muse', 'mutect', 'somaticsniper', 'varscan')

possible_cancers = ('ACC', 'BLCA')#,'BRCA','CESC','CHOL','COAD','DLBC','ESCA','GBM','HNSC', 
                    #'KICH','KIRC','KIRP','LAML','LGG','LIHC','LUAD','LUSC','MESO', 'OV','PAAD',
                    #'PCPG','PRAD','READ','SARC','SKCM','STAD','TGCT','THCA','THYM','UCEC','UCS','UVM')

original = os.getcwd()
for cancer in possible_cancers:
    os.chdir(original)
    os.chdir(cancer)
    mafs = os.listdir()

    maf_fps = {}
    for caller in possible_callers:
        for maf in mafs:    
            if caller in maf: # str in the filepath
                maf_fps[caller] = maf

    all_variants = {}
    
    for caller in maf_fps:
        all_variants[caller] = parse_maf(maf_fps[caller])
        print(all_variants[caller])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#                                      #version gdc-1.0.0
# 0                                    #filedate 20170929
# 1                     #annotation.spec gdc-1.0.1-public
# 2                                #n.analyzed.samples 92
# 3     #tumor.aliquots.submitter_id TCGA-OR-A5J1-01A-...
# 4     Hugo_Symbol\tEntrez_Gene_Id\tCenter\tNCBI_Buil...
# 5     CTBS\t1486\tBCM\tGRCh38\tchr1\t84570701\t84570...
# 6     ATF6\t22926\tBCM\tGRCh38\tchr1\t161791444\t161...
# 7     SLC35F3\t148641\tBCM\tGRCh38\tchr1\t234309160\...
# 8     TTN\t7273\tBCM\tGRCh38\tchr2\t178704929\t17870...
# 9     SP140\t11262\tBCM\tGRCh38\tchr2\t230238312\t23...
# ...

# %%
print(all_variants['muse'].iloc['Hugo_Symbol'][4])

# %%
print(list(all_variants['muse'].columns)[0].split('\t'))
